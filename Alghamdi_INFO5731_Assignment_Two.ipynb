# %% [markdown]
# <a href="https://colab.research.google.com/github/AsmaaAlghamd1/Asmaa_INFO5731_-Spring2021/blob/main/Alghamdi_INFO5731_Assignment_Two.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **INFO5731 Assignment Two**
#
# In this assignment, you will try to gather text data from open data source via web scraping or API. After that you need to clean the text data and syntactic analysis of the data.

# %% [markdown]
# # **Question 1**

# %% [markdown]
# (40 points). Write a python program to collect text data from **either of the following sources** and save the data into a **csv file**:
#
# (1) Collect all the customer reviews of the product [2019 Dell labtop](https://www.amazon.com/Dell-Inspiron-5000-5570-Laptop/dp/B07N49F51N/ref=sr_1_11?crid=1IJ7UWF2F4GHH&keywords=dell%2Bxps%2B15&qid=1580173569&sprefix=dell%2Caps%2C181&sr=8-11&th=1) on amazon.
#
# (2) Collect the top 100 User Reviews of the film [Joker](https://www.imdb.com/title/tt7286456/reviews?ref_=tt_urv) from IMDB.
#
# (3) Collect the abstracts of the top 100 research papers by using the query [natural language processing](https://citeseerx.ist.psu.edu/search?q=natural+language+processing&submit.x=0&submit.y=0&sort=rlv&t=doc) from CiteSeerX.
#
# (4) Collect the top 100 tweets by using hashtag ["#CovidVaccine"](https://twitter.com/hashtag/CovidVaccine) from Twitter.

# %%
#  Collect the top 100 tweets by using hashtag "#CovidVaccine" from Twitter.
import tweepy 
import re
import csv
import pandas as pd
import re
import string
import nltk
from nltk.stem import PorterStemmer
from textblob import Word
from tweepy import OAuthHandler


consumer_key = "Qw9FJDUSlEr3qqMcQCsmiWu0n"
consumer_secret = "NXm3s8Vo2DmWjvj1ABT30pFOUXNz6z8ApTfU9ycOsFFcAwH2j2"
access_key = "1326295350408335366-7V4F8boH5JtgzDvgClngFR7QyXc9Nw"
access_secret = "VligfO23x5m3LwuoRErb72O10wnUxgy5BIlzp8TM7XFKZ"


auth = tweepy.OAuthHandler(consumer_key, consumer_secret) 
auth.set_access_token(access_key, access_secret) 
api = tweepy.API(auth,wait_on_rate_limit=True)
  
My_tweets = []
search_query = '#CovidVaccine'
CsvFile = open('List_tweets.csv', 'a')
for tweet in tweepy.Cursor(api.search,q=search_query+" -filter:retweets",lang='en',result_type='recent').items(100):
  csvWriter = csv.writer(CsvFile)
  print(My_tweets)
  print(tweet.text)
  csvWriter.writerow([tweet.text.encode('utf-8')])
# Out:
# []
# I got a Covid-19 vaccine appointment Monday morning 8:03am!!! I feel like I won the lottery! #COVIDVaccine
# []
# US Nods Johnson &amp; Johnson Single-Shot Covid Vaccine For Emergency Use
# #LatestNews #US #CovidVaccine
# https://t.co/HApRMvVoRo
# []
# FDA Approves Janssen (Johnson &amp; Johnson) COVID vaccine.
# Only ⚠️42% ⚠️effective in persons 60 and older with underly… https://t.co/HczqmiHXlk
# []
# And now authorization for the £#johnsonandjohnson #COVIDVaccine!  Now another manufacturer will lend its weight to… https://t.co/gWn7cjLQgh
# []
# What should happen to people who lie about their Covid vaccine eligibility? Vote now:  https://t.co/UujnAunWMp… https://t.co/gSb5CCWzWh
# []
# What an amazing community event Almost 750 shots given in Chesapeake, VA. Thanks to all the volunteers from… https://t.co/u4Q4qjV9zj
# []
# Flexibilities for the @pfizer #COVIDVaccine which will allow easier and more widespread use. https://t.co/hADftMtXUy.
# []
# ...

# %% [markdown]
# # **Question 2**

# %% [markdown]
# (30 points). Write a python program to **clean the text data** you collected above and save the data in a new column in the csv file. The data cleaning steps include:
#
# (1) Remove noise, such as special characters and punctuations.
#
# (2) Remove numbers.
#
# (3) Remove stopwords by using the [stopwords list](https://gist.github.com/sebleier/554280).
#
# (4) Lowercase all texts
#
# (5) Stemming.
#
# (6) Lemmatization.

# %%
d = pd.read_csv("List_tweets.csv",sep='\t',names=['tweets'])
import string

d['Remove Noise'] = d['tweets'].apply(lambda x: " ".join(x for x in x.split() if x.isalnum()))
d[['Remove Noise','tweets']].head(n=100)
# Out:
#                                          Remove Noise                                             tweets
# 0   for the which will allow easier and more wides...  b'Flexibilities for the @pfizer #COVIDVaccine ...
# 1   may not be on campus together but that mean yo...  b'We may not be on campus together but that do...
# 2                             Most of the states said  b'@XpressHyderabad @chetanabelagere @XpressBen...
# 3                                     then there were  b'And then there were three... #COVID19 #COVID...
# 4                           Why was Quit changing the  b'\xf0\x9f\x98\xa1\xf0\x9f\x98\xa1\xf0\x9f\x98...
# ..                                                ...                                                ...
# 95           spent 30 mins playing the vaccine appt I  b'Just spent 30 mins playing the vaccine appt ...
# 96  1 fever headache on and off off than arm still...  b'Dose 1 update: fever gone... headache on and...
# ...

# %%
# Remove special characters
d['Special Character Remover'] = d['Remove Noise'].str.replace("[^a-zA-Z#]+", " ").str.strip()
d[['Special Character Remover','Remove Noise']].head(n=100)
# Out:
#                             Special Character Remover                                       Remove Noise
# 0   for the which will allow easier and more wides...  for the which will allow easier and more wides...
# 1   may not be on campus together but that mean yo...  may not be on campus together but that mean yo...
# 2                             Most of the states said                            Most of the states said
# 3                                     then there were                                    then there were
# 4                           Why was Quit changing the                          Why was Quit changing the
# ..                                                ...                                                ...
# 95              spent mins playing the vaccine appt I           spent 30 mins playing the vaccine appt I
# 96  fever headache on and off off than arm still O...  1 fever headache on and off off than arm still...
# ...

# %%
# Remove numbers
d["Remove numbers"] = d['Special Character Remover'].str.rstrip(string.digits)
d[["Remove numbers",'Special Character Remover']].head(n=100)
# Out:
#                                        Remove numbers                          Special Character Remover
# 0   for the which will allow easier and more wides...  for the which will allow easier and more wides...
# 1   may not be on campus together but that mean yo...  may not be on campus together but that mean yo...
# 2                             Most of the states said                            Most of the states said
# 3                                     then there were                                    then there were
# 4                           Why was Quit changing the                          Why was Quit changing the
# ..                                                ...                                                ...
# 95              spent mins playing the vaccine appt I              spent mins playing the vaccine appt I
# 96  fever headache on and off off than arm still O...  fever headache on and off off than arm still O...
# ...

# %%
#lower casing
d['lower casing']=d["Remove numbers"].apply(lambda x: " ".join(x.lower() for x in x.split()))
d[["Remove numbers",'lower casing']].head(n=100)
# Out:
#                                        Remove numbers                                       lower casing
# 0   for the which will allow easier and more wides...  for the which will allow easier and more wides...
# 1   may not be on campus together but that mean yo...  may not be on campus together but that mean yo...
# 2                             Most of the states said                            most of the states said
# 3                                     then there were                                    then there were
# 4                           Why was Quit changing the                          why was quit changing the
# ..                                                ...                                                ...
# 95              spent mins playing the vaccine appt I              spent mins playing the vaccine appt i
# 96  fever headache on and off off than arm still O...  fever headache on and off off than arm still o...
# ...

# %%
#Remove stop words
from nltk.corpus import stopwords
nltk.download('stopwords')
stop=stopwords.words('english')

d['Stop words removal']=d['lower casing'].apply(lambda x:" ".join(x for x in x.split() if x not in stop))
d[['Stop words removal','lower casing']].head(n=100)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#                                    Stop words removal                                       lower casing
# 0                             allow easier widespread  for the which will allow easier and more wides...
# 1                 may campus together mean run fellow  may not be on campus together but that mean yo...
# 2                                         states said                            most of the states said
# 3                                                                                        then there were
# 4                                       quit changing                          why was quit changing the
# ..                                                ...                                                ...
# 95                    spent mins playing vaccine appt              spent mins playing the vaccine appt i
# ...

# %%
#Remove punctuations

d['Punctuations removal']=d['Stop words removal'].str.replace('[^\w\s]','')
d[['Punctuations removal','Stop words removal']].head(n=100)
# Out:
#                                  Punctuations removal                                 Stop words removal
# 0                             allow easier widespread                            allow easier widespread
# 1                 may campus together mean run fellow                may campus together mean run fellow
# 2                                         states said                                        states said
# 3
# 4                                       quit changing                                      quit changing
# ..                                                ...                                                ...
# 95                    spent mins playing vaccine appt                    spent mins playing vaccine appt
# 96            fever headache arm still otherwise dose            fever headache arm still otherwise dose
# 97                                          knew good                                          knew good
# ...

# %%
#lemmatization

nltk.download('wordnet')
d['lemmatization']=d['Punctuations removal'].apply(lambda x: " ".join([Word(word).lemmatize() for word in x.split()]))
d[['lemmatization','Punctuations removal']].head(n=100)
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
#                                         lemmatization                               Punctuations removal
# 0                             allow easier widespread                            allow easier widespread
# 1                 may campus together mean run fellow                may campus together mean run fellow
# 2                                          state said                                        states said
# 3
# 4                                       quit changing                                      quit changing
# ..                                                ...                                                ...
# 95                     spent min playing vaccine appt                    spent mins playing vaccine appt
# 96            fever headache arm still otherwise dose            fever headache arm still otherwise dose
# ...

# %%
#stemming

st=PorterStemmer()

d['Stemming']=d['lemmatization'].apply(lambda x: " ".join([st.stem(word) for word in x.split()]))
d[['Stemming','lemmatization']].head(n=100)
# Out:
#                                              Stemming                                      lemmatization
# 0                             allow easier widespread                            allow easier widespread
# 1                    may campu togeth mean run fellow                may campus together mean run fellow
# 2                                          state said                                         state said
# 3
# 4                                          quit chang                                      quit changing
# ..                                                ...                                                ...
# 95                         spent min play vaccin appt                     spent min playing vaccine appt
# 96              fever headach arm still otherwis dose            fever headache arm still otherwise dose
# 97                                          knew good                                          knew good
# ...

# %%
d
# Out:
#                                                 tweets  ...                          Stemming
# 0    b'Flexibilities for the @pfizer #COVIDVaccine ...  ...           allow easier widespread
# 1    b'We may not be on campus together but that do...  ...  may campu togeth mean run fellow
# 2    b'@XpressHyderabad @chetanabelagere @XpressBen...  ...                        state said
# 3    b'And then there were three... #COVID19 #COVID...  ...
# 4    b'\xf0\x9f\x98\xa1\xf0\x9f\x98\xa1\xf0\x9f\x98...  ...                        quit chang
# ..                                                 ...  ...                               ...
# 251  b'Everything you need to know about the vaccin...  ...  need know roll phase build immun
# 252  b'The Day 340 COVID-19 Report of India || ABC ...  ...   day report india abc live india
# 253  b'Everything you need to know about the vaccin...  ...  need know roll phase build immun
# ...

# %%
d.to_csv("Second_version.csv",index= False)

Version2 = pd.read_csv("/content/Second_version.csv")

# %%
colname1 = ['Uncleaned']
df1=pd.read_csv("List_tweets.csv",names= colname1)

df1
# Out:
#                                              Uncleaned
# 0    b'Flexibilities for the @pfizer #COVIDVaccine ...
# 1    b'We may not be on campus together but that do...
# 2    b'@XpressHyderabad @chetanabelagere @XpressBen...
# 3    b'And then there were three... #COVID19 #COVID...
# 4    b'\xf0\x9f\x98\xa1\xf0\x9f\x98\xa1\xf0\x9f\x98...
# ..                                                 ...
# 251  b'Everything you need to know about the vaccin...
# 252  b'The Day 340 COVID-19 Report of India || ABC ...
# 253  b'Everything you need to know about the vaccin...
# 254  b'Everything you need to know about the vaccin...
# 255  b'I take it back, my arm fucking hurts #covidv...
#
# [256 rows x 1 columns]

# %%
colname2 = ['Cleaned data']
df2 = pd.read_csv("Second_version.csv",names=colname2)

df2
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                      Cleaned data
# tweets                                             Remove Noise                                       Special Character Remover                          Remove numbers                                     lower casing                                       Stop words removal                    Punctuations removal                  lemmatization                                                 Stemming
# ...

# %% [markdown]
# # **Question 3**

# %% [markdown]
# (30 points). Write a python program to conduct **syntax and structure analysis** of the clean text you just saved above. The syntax and structure analysis includes:
#
# (1) Parts of Speech (POS) Tagging: Tag Parts of Speech of each word in the text, and calculate the total number of N(oun), V(erb), Adj(ective), Adv(erb), respectively.
#
# (2) Constituency Parsing and Dependency Parsing: print out the constituency parsing trees and dependency parsing trees of all the sentences. Using one sentence as an example to explain your understanding about the constituency parsing tree and dependency parsing tree.
#
# (3) Named Entity Recognition: Extract all the entities such as person names, organizations, locations, product names, and date from the clean texts, calculate the count of each entity.

# %%
#Parts of Speech (POS) Tagging
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('universal_tagset')
Version2
from nltk.tokenize import word_tokenize 

Pos_tag=[]
freq=[]
x=0
for i in d['Stemming']:
  token=nltk.word_tokenize(i)
  Pos_tag.append(nltk.pos_tag(token,tagset='universal'))
  freq.append(nltk.FreqDist(tag for (word, tag) in Pos_tag[0]))
  print(Pos_tag[x])
  print(freq[x])
  x=x+1
print(freq)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package universal_tagset to /root/nltk_data...
# [nltk_data]   Package universal_tagset is already up-to-date!
# [('allow', 'ADV'), ('easier', 'ADJ'), ('widespread', 'ADJ')]
# <FreqDist with 2 samples and 3 outcomes>
# [('may', 'VERB'), ('campu', 'VERB'), ('togeth', 'ADJ'), ('mean', 'ADJ'), ('run', 'NOUN'), ('fellow', 'NOUN')]
# <FreqDist with 2 samples and 3 outcomes>
# [('state', 'NOUN'), ('said', 'VERB')]
# <FreqDist with 2 samples and 3 outcomes>
# []
# <FreqDist with 2 samples and 3 outcomes>
# [('quit', 'NOUN'), ('chang', 'NOUN')]
# <FreqDist with 2 samples and 3 outcomes>
# ...

# %%
# calculate the total number of N(oun), V(erb), Adj(ective), Adv(erb), respectively.

from nltk import pos_tag_sents
nltk.download('averaged_perceptron_tagger')
POS_word = pos_tag_sents( d['tweets'].apply(word_tokenize).tolist() )

A=0
B=0
C=0
D=0
for x in POS_word:
 for y in x:
   for z in y:
        if z =='NN':
          A=A+1
        elif z =='VBP':
          B=B+1
        elif z =='RB':
          C=C+1
        elif z =='JJ':
          D= D+1
        else: 0

print("The total number of Noun:",A)        
print("The total number of Verbs:",B)
print("The total number of Adverbs :",C)
print("The total number of Adjectives :",D)
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# The total number of Noun: 1214
# The total number of Verbs: 115
# The total number of Adverbs : 194
# The total number of Adjectives : 481

# %%
## Constituency Parsing and Dependency Parsing

# %%
# !pip install benepar

# %%
import spacy
import benepar
from benepar.spacy_plugin import BeneparComponent
benepar.download('benepar_en')
benepar.download('benepar_en3')
import nltk.draw.tree
# Out:
# /usr/local/lib/python3.7/dist-packages/benepar/spacy_plugin.py:12: FutureWarning: BeneparComponent and NonConstituentException have been moved to the benepar module. Use `from benepar import BeneparComponent, NonConstituentException` instead of benepar.spacy_plugin. The benepar.spacy_plugin namespace is deprecated and will be removed in a future version.
#   FutureWarning,
# [nltk_data] Error loading benepar_en: Package 'benepar_en' not found
# [nltk_data]     in index
# [nltk_data] Downloading package benepar_en3 to /root/nltk_data...
# [nltk_data]   Package benepar_en3 is already up-to-date!

# %%
nlp = spacy.load('en')
nlp.add_pipe(BeneparComponent('benepar_en3'))
parser= benepar.Parser("benepar_en3")
for i in d['Stemming']:
  try:
    x = parser.parse(i)
    print(x)
  except:
    print("Nothing to show")
    continue
# Out:
# (TOP (S (VP (VB allow) (NP (JJR easier) (JJ widespread)))))
# (TOP
#   (VP
#     (MD may)
#     (VP
#       (VB campu)
#       (NN togeth)
#       (VP (VB mean) (NP (VB run) (NP (NN fellow)))))))
# (TOP (SINV (NP (NN state)) (VP (VBD said))))
# Nothing to show
# (TOP (VP (VB quit) (NP (NN chang))))
# (TOP
#   (VP
#     (VBD got)
#     (NP (PRP mine))
#     (NN vaccin)
#     (JJ first)
#     (NN thing)
#     (RB well)
#     (VB thank)
#     (NP (NN governor) (NNP carney))
#     (VB thank)))
# (TOP (VP (VB tread) (NP (NN water))))
# (TOP
#   (FRAG
#     (ADJP (JJ clear) (NN johnson))
#     (NN johnson)
#     (NN covid)
#     (NN vaccin)
#     (VP (VBP emerg) (NP (NN use)))))
# (TOP (NP (NN event)))
# (TOP
#   (NP
#     (FW realli)
#     (FW angri)
#     (FW peopl)
#     (JJ bioethic)
#     (NN think)
#     (JJ blatant)
#     (NN ableism)))
# (TOP
#   (S
#     (NP (NN mani))
#     (VP
#       (VB say)
#       (SBAR
#         (IN whether)
#         (S
# ...

# %%
import spacy
nlp=spacy.load('en_core_web_sm')
from spacy import displacy
for x in d['Stemming']:
  Y=nlp(x)
  displacy.render(Y,jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="4f2499d7d2814a7494c4711260452e35-0" class="displacy" width="575" height="312.0" direction="ltr" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">allow</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">easier</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
# ...

# %%
##Named Entity Recognition

dict1=[]
nlp = spacy.load('en_core_web_sm')
for i in range(0,100):
  for x in d['Stemming']:
    Y=nlp(x)
    for ent in Y.ents:
      if ent.label_ and ent.text :
        dict1.append((ent.label_,ent.text,))
      print([(ent.label_,ent.text)])
# Out:
# Streaming output truncated to the last 5000 lines.
# [('PERSON', 'grant emerg')]
# [('PERSON', 'joe biden')]
# [('PERSON', 'anyon')]
# [('PERSON', 'appar')]
# [('ORDINAL', 'second')]
# [('PERSON', 'giant commun')]
# [('ORDINAL', 'second')]
# [('PERSON', 'fever headach')]
# [('PERSON', 'carri bath')]
# [('ORG', 'nd')]
# [('ORG', 'state')]
# [('PERSON', 'quit chang')]
# [('PERSON', 'johnson johnson')]
# [('PERSON', 'realli angri peopl')]
# [('GPE', 'u rd')]
# [('ORG', 'kinda sore gon')]
# [('ORG', 'covid vaccin offici')]
# [('PERSON', 'moderna astrazeneca')]
# [('CARDINAL', 'battl')]
# [('ORG', 'massachusett state vaccin')]
# [('PERSON', 'someon histori')]
# [('PERSON', 'mani issu rel vaccin')]
# [('GPE', 'hospit')]
# [('PERSON', 'sooo damn')]
# [('GPE', 'india')]
# [('ORG', 'abc')]
# [('GPE', 'india')]
# [('PERSON', 'bingo')]
# [('ORG', 'covid vaccin arriv australia')]
# [('PERSON', 'everyon')]
# [('PERSON', 'tri chang focu')]
# [('DATE', 'march citizen year')]
# ...

# %%
H = 0
I = 0
J = 0
K = 0
L = 0
M = 0 
N=0

for x in range(0,100):
  text = nlp(d['Stemming'][x])
  for ent in text.ents:
    if ent.label_ == "DATE":
       H=H+1
    elif ent.label_ == "TIME":
       I=I+1
    elif ent.label_ == "CARDINAL":
       J=J+1
    elif ent.label_ == "ORDINAL":
       K=K+1
    elif ent.label_ == "NORP":
       L=L+1
    elif ent.label_ == "ORG":
       M=M+1
    elif ent.label_ == "PERSON":
       N=N+1
    else: 0
    print(ent.text, ent.label_)
print("DATE:",H) 
print("TIME:",I) 
print("CARDINAL:",J) 
print("ORDINAL:",K) 
print("NORP:",L) 
print("ORG:",M)
print("PERSON:",N)
# Out:
# state ORG
# quit chang PERSON
# johnson johnson PERSON
# realli angri peopl PERSON
# u rd GPE
# kinda sore gon ORG
# covid vaccin offici ORG
# moderna astrazeneca PERSON
# battl CARDINAL
# massachusett state vaccin ORG
# someon histori PERSON
# mani issu rel vaccin PERSON
# hospit GPE
# sooo damn PERSON
# india GPE
# abc ORG
# india GPE
# bingo PERSON
# covid vaccin arriv australia ORG
# everyon PERSON
# tri chang focu PERSON
# march citizen year DATE
# age bracket year DATE
# approv johnson PERSON
# cbc ORG
# health offici PERSON
# elderli post ORG
# india GPE
# abc ORG
# india GPE
# lou gotten PERSON
# first ORDINAL
# vermont GPE
# first ORDINAL
# bicep ORG
# anybodi die PERSON
# saturday DATE
# third ORDINAL
# johnson johnson PERSON
# accur news ORG
# vaccin johnson johnson PERSON
# proud team ORG
# aurora baycar PERSON
# million CARDINAL
# second ORDINAL
# one CARDINAL
# approv johnson johnson vaccin PERSON
# proud fam help vaccin ORG
# million CARDINAL
# grant emerg PERSON
# ...

# %% [markdown]
# **Write your explanations of the constituency parsing tree and dependency parsing tree here (Question 3-2):**

# %% [markdown]
# '''
# Constituency and dependency parsing trees are two methods that use different types of grammars.
#
# The constituency parse tree is a very useful representation tool to show the syntactical structure of the sentence. It represents the data in a hierarchical model and divides the sentences into single phrases(sub-phrases).
#
# The Dependency parsing doesn't make use of sub-phrases.
# The Dependency parsing represents a graph that shows the relationships between the words.
# As we can see in the above example, the tree's root is the sentence's verbs, and edges among words express their relationships.
# '''
